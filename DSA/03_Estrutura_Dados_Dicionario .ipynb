# %%
#Criando um dicionario
estudantes = {"alexandre":1, "ivoneide":2, "lombarde":3}
estudantes ["ivoneide"]
# Out:
# 2

# %%
#Acrescentar elemento
estudantes["Alex"]=4
estudantes
# Out:
# {'Alex': 4, 'alexandre': 1, 'ivoneide': 2, 'lombarde': 3}

# %%
#Extrair chaves
estudantes.keys()
# Out:
# dict_keys(['alexandre', 'ivoneide', 'lombarde', 'Alex'])

# %%
#Extrair valores
estudantes.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
#Extrair itens
estudantes.items()
# Out:
# dict_items([('alexandre', 1), ('ivoneide', 2), ('lombarde', 3), ('Alex', 4)])

# %%
#Concatenação / Update
estudantes2 = {"leandro":4,"daniela":5}
estudantes.update(estudantes2)
estudantes
# Out:
# {'Alex': 4,
#  'alexandre': 1,
#  'daniela': 5,
#  'ivoneide': 2,
#  'leandro': 4,
#  'lombarde': 3}

# %%
#Unindo dicionarios com lista
dicionario = {"list1":1,"list2":[2,3,4],"list3":5}
dicionario
# Out:
# {'list1': 1, 'list2': [2, 3, 4], 'list3': 5}

# %%
#printando um elemento
print(dicionario["list2"])
print(dicionario["list2"][0])
# Out:
# [2, 3, 4]
# 2

# %%
# Definindo sets, sets nao podem ser repetidos
classmate = {"alex", "andre","lombarde","andre"}
friends = {"costa", "Lombarde"}

# %%
# imprimindo uniao
uniao = classmate.union(friends)
print(uniao)
# imprimindo intersecao
print(friends.intersection(uniao))
# imprimindo diferença (mostra os itens presentes na primeira lista"classmate" e nao presentes na segunda"friends")
print(classmate.difference(friends))
# Out:
# {'lombarde', 'andre', 'Lombarde', 'costa', 'alex'}
# {'costa', 'Lombarde'}
# {'lombarde', 'andre', 'alex'}
