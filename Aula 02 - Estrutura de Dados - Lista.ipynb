# %%
#Criação da Lista
lista1 = ["ovos", "farinha", "leite", "macas"]
print (lista1)
# Out:
# ['ovos', 'farinha', 'leite', 'macas']

# %%
#Criação de Lista de diferentes tipos
lista2 = [12, 100, "universidade"]
print (lista2)
# Out:
# [12, 100, 'universidade']

# %%
#Atualizando itens da Lista
lista1 [2]
# Out:
# 'leite'

# %%
lista1 [2] = "chocolate"
lista1 [2]
# Out:
# 'chocolate'

# %%
#Deletar item da lista
del lista1 [3]

# %%
lista1 [3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-14e29f4760d5> in <module>()
# ----> 1 lista1 [3]
#
# IndexError: list index out of range

# %%
#Criando lista de listas
lista3 = [[1,2,3],[10,11,12]]
lista3 [0]
# Out:
# [1, 2, 3]

# %%
#Criando variavel para extrair sublista
a = lista3 [0]
b = a[0]
b
# Out:
# 1

# %%
#Concatenar listas
lista_a = lista3 [0]
lista_b = lista3 [1]
lista_total = lista_a + lista_b
lista_total
# Out:
# [1, 2, 3, 10, 11, 12]

# %%
#Pesquisar itens em listas
print (10 in lista_total)
# Out:
# True

# %%
#Tamanho da lista
len(lista_total)
# Out:
# 6

# %%
#Maior e Menor numero da lista
max(lista_total)
min(lista_total)
# Out:
# 1

# %%
#Adicionar e Remover itens a lista
lista_total.append(21)
lista_total.remove(21)
lista_total
# Out:
# [12, 11, 10, 23, 23, 2, 1]

# %%
#ìndice da Lista para um elemento
lista_total.index (11)
# Out:
# 4

# %%
#inserir item na lista com indice
lista_total.insert(3, 23)
lista_total
# Out:
# [12, 11, 10, 23, 23, 23, 2, 1]

# %%
#Inverter lista
lista_total.reverse()
lista_total
# Out:
# [1, 2, 23, 23, 23, 10, 11, 12]

# %%
#Ordernar lista
lista_total.sort()
lista_total
# Out:
# [1, 2, 23, 23, 23, 10, 11, 12]
