# %%
#Tuplas são dados que não podem ser alterados interessante apenas para calendarios por exemplo tuplas sao criadas com (), lista com [] e dicionario com {}
#Criando Tuplas
tupla1 = ("geografia",23,"Elefante")

# %%
#Como a tupla nao pode ser alterado, caso necessite alteração pode converter a tupla em lista, alterar e converter a lista em tupla novamente
lista1 = list(tupla1)
lista1 [1] = 25
tupla1 = tuple(lista1)
tupla1
# Out:
# ('geografia', 25, 'Elefante')
