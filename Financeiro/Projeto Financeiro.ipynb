# %%
# importanto bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
# carregando arquivos csv
dados = pd.read_csv('EURUSD_Daily_202201030000_202209190000.csv', sep='\t')
display(dados)
# Out:
#          <DATE>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  <TICKVOL>  <VOL>  \
# 0    2022.01.03  1.13693  1.13778  1.12795  1.12971      53813      0
# 1    2022.01.04  1.12961  1.13226  1.12723  1.12862      62525      0
# 2    2022.01.05  1.12852  1.13466  1.12765  1.13135      61289      0
# 3    2022.01.06  1.13111  1.13316  1.12846  1.12976      67251      0
# 4    2022.01.07  1.12960  1.13647  1.12901  1.13590      49836      0
# ..          ...      ...      ...      ...      ...        ...    ...
# 181  2022.09.13  1.01207  1.01873  0.99663  0.99686     118597      0
# 182  2022.09.14  0.99674  1.00236  0.99551  0.99814     132052      0
# 183  2022.09.15  0.99781  1.00181  0.99556  0.99966      89766      0
# 184  2022.09.16  0.99975  1.00367  0.99444  1.00129     102107      0
# 185  2022.09.19  1.00043  1.00291  0.99659  1.00243      74730      0
#
#      <SPREAD>
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 181         0
# ...

# %%
# plotando grafico simples
plt.plot(dados['<DATE>'],dados['<CLOSE>'])
plt.show()
